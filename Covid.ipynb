# %% [markdown]
# # Covid Analysys from a common perspective
# ## Data Sources:
#     * healthdata.gov
#     *

# %%
import pandas as pd

# %%
covidData = pd.read_csv('./DataSets/covid_dayly.csv')
testing = pd.read_csv('./DataSets/20210131_2252.csv')

# %%
covidData.head()
# Out:
#         date      country  cumulative_total_cases  daily_new_cases  \
# 0  2020-2-15  Afghanistan                     0.0              NaN
# 1  2020-2-16  Afghanistan                     0.0              NaN
# 2  2020-2-17  Afghanistan                     0.0              NaN
# 3  2020-2-18  Afghanistan                     0.0              NaN
# 4  2020-2-19  Afghanistan                     0.0              NaN
#
#    active_cases  cumulative_total_deaths  daily_new_deaths
# 0           0.0                      0.0               NaN
# 1           0.0                      0.0               NaN
# 2           0.0                      0.0               NaN
# 3           0.0                      0.0               NaN
# 4           0.0                      0.0               NaN

# %%
data.describe(include="all")
# Out:
#              date country  cumulative_total_cases  daily_new_cases  \
# count       77769   77769            7.776900e+04     71300.000000
# unique        379     219                     NaN              NaN
# top     2021-1-18   China                     NaN              NaN
# freq          219     379                     NaN              NaN
# mean          NaN     NaN            1.421095e+05      1471.046704
# std           NaN     NaN            8.955497e+05      8738.262423
# min           NaN     NaN            0.000000e+00     -1417.000000
# 25%           NaN     NaN            9.200000e+01         0.000000
# 50%           NaN     NaN            2.335000e+03        27.000000
# 75%           NaN     NaN            3.065300e+04       380.000000
# max           NaN     NaN            2.715046e+07    308309.000000
#
#         active_cases  cumulative_total_deaths  daily_new_deaths
# count   7.670400e+04             71379.000000      60095.000000
# ...

# %%
testing.describe(include="all")
# Out:
#         state  state_name    state_fips fema_region overall_outcome  \
# count   52138       52138  52138.000000       52138           52138
# unique     54          54           NaN          10               3
# top        WA  Washington           NaN    Region 4        Negative
# freq     1008        1008           NaN        7908           17775
# mean      NaN         NaN     30.827688         NaN             NaN
# std       NaN         NaN     17.644496         NaN             NaN
# min       NaN         NaN      1.000000         NaN             NaN
# 25%       NaN         NaN     17.000000         NaN             NaN
# 50%       NaN         NaN     30.000000         NaN             NaN
# 75%       NaN         NaN     44.000000         NaN             NaN
# max       NaN         NaN     78.000000         NaN             NaN
#
#               date  new_results_reported  total_results_reported
# count        52138          52138.000000            5.213800e+04
# ...
